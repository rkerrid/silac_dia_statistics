# %% [markdown]
# # Preprocessing (normalize)

# %%
from sdia_stats.preprocessing import adapted_imputation 
from sdia_stats.preprocessing import normalize_samples
from sdia_stats.preprocessing import filter_contams_and_non_valid_rows

# %%
meta = 'G:/My Drive/Data/data/20240410 SRP AID/meta.csv'
path = 'G:/My Drive/Data/data/20240410 SRP AID/'
path = 'G:/My Drive/Data/data/POC5/'
meta = 'G:/My Drive/Data/data/POC5/meta.csv'

# %%
group = {'control': ['Len','ARV825','DFO', 'Gu', 'FAC', '4EGI']
              }
normalize_samples.main(path, group, meta)
# Out:
# [('control', 'Len', 0.0352364065890427), ('control', 'ARV825', 0.13610918815166073), ('control', 'DFO', 0.04168797039567096), ('control', 'Gu', 0.02161502403250637), ('control', 'FAC', 0.026098101709841615), ('control', '4EGI', 0.021124868506980476)]
# Folder reports created successfully at G:/My Drive/Data/data/POC5//statistics/normalized
