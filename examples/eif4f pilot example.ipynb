# %%
from sdia_stats.visualization import interpret_ttest_results
#from sdia_stats.visualization.interpret_ttest import loop_and_plot_results

# %%
path = 'G:/My Drive/Data/data/eIF4F pilot/imputed/ttest results/'

# %%
pois = ['EIF4G1', 'EIF4G2', 'EIF4E']

# %%
interpret_ttest_results.loop_and_plot_results(path, pois, uniprot=False)
# Out:
# ['g2_total.csv', 'g2_light.csv', 'g3_light.csv', 'g1_light.csv', 'e_light.csv', 'g1_total.csv', 'e_total.csv', 'g3_total.csv', 'g3_nsp.csv', 'g1_nsp.csv', 'g2_nsp.csv', 'e_nsp.csv', 'desktop.ini']
# ...
# Output()
# Output()
# Output()
# ...
# Output()
# Output()
# Output()
# ...
# Output()
# Output()
# Output()
# ...
# Output()
# Output()
# Output()
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 interpret_ttest_results.loop_and_plot_results(path, pois, uniprot=False)
#
# File c:\phd projects\silac_dia_statistics\sdia_stats\visualization\interpret_ttest_results.py:235, in loop_and_plot_results(path, pois, uniprot)
#     233 for result in result_list:
#     234     name = result[:-4]
# --> 235     df = pd.read_csv(f'{path}/{result}')
#     236     if len(df) > 1000:
#     237         # df = reduce_df_size(df, 1000)
# ...
