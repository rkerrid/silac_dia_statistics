# %%
# clustermap anova

# %%
from sdia_stats.visualization import clustermap_anova

# %%
path = 'G:/My Drive/Data/data/poc4/H/imputed/normalized/for_anova/'

# %%
samples = ['control_I', 'control_II', 'control_III', 'FAC_I','FAC_II','FAC_III']

# %%
clustermap_anova.plot_clustermap(path, samples)
# Out:
# ic| light_df:                        Protein.Group  control_I  control_I.1  control_I.2  \
#               0     A0A0B4J2D5;P0DPI2-GATD3;GATD3B   2.778157     2.778157     2.778157
#               1                   A0A3B3IRV3-MCTS2   0.101858     0.101858     0.101858
#               2                       A0AV96-RBM47   0.143552     0.143552     0.143552
#               3                       A0AVF1-TTC26   0.308162     0.308162     0.308162
#               4                        A0AVT1-UBA6   4.417841     4.417841     4.417841
#               ...                              ...        ...          ...          ...
#               5393                  Q9Y6X4-FAM169A   0.515914     0.515914     0.515914
#               5394                    Q9Y6X5-ENPP4   0.136924     0.136924     0.136924
#               5395                     Q9Y6X8-ZHX2   0.099504     0.099504     0.099504
#               5396                    Q9Y6X9-MORC2   1.938080     1.938080     1.938080
#               5397                  Q9Y6Y8-SEC23IP   4.376767     4.376767     4.376767
#
#                        FAC_I    FAC_II   FAC_III
#               0     2.661565  3.041689  2.805746
#               1     0.060358  0.078102  0.180741
#               2     0.064787  0.061104  0.217736
#               3     0.389782  0.250218  0.479904
#               4     4.796469  4.897395  4.677072
#               ...        ...       ...       ...
#               5393  0.565789  0.500319  0.509044
#               5394  0.131676  0.131349  0.110375
#               5395  0.044481  0.200614  0.056242
#               5396  1.712576  1.866969  2.245344
#               5397  4.753616  4.425123  5.293944
#
#               [5398 rows x 7 columns]
# ic| merged_df:                        Protein.Group  control_I  control_I.1  control_I.2  \
#                0     A0A0B4J2D5;P0DPI2-GATD3;GATD3B   1.209606     1.209606     1.209606
#                1                        A0A1B0GUL7-   0.034609     0.034609     0.034609
#                2            A0A1W2PQ72-LOC100421372   0.029444     0.029444     0.029444
#                3                       A0AVF1-TTC26   0.041750     0.041750     0.041750
#                4                        A0AVT1-UBA6   1.680600     1.680600     1.680600
#                ...                              ...        ...          ...          ...
#                5050                     Q9Y6X3-MAU2   0.108682     0.108682     0.108682
#                5051                    Q9Y6X5-ENPP4   0.080272     0.080272     0.080272
#                5052                     Q9Y6X8-ZHX2   0.049117     0.049117     0.049117
#                5053                    Q9Y6X9-MORC2   1.095462     1.095462     1.095462
#                5054                  Q9Y6Y8-SEC23IP   1.701476     1.701476     1.701476
#
#                         FAC_I    FAC_II   FAC_III  ANOVA_pvalue  FAC vs. control Tukey Test
#                0     0.873519  1.049286  1.241874      0.220890                    0.220890
#                1     0.038361  0.050607  0.395022      0.307645                    0.307645
#                2     0.059797  0.045289  0.056833      0.004049                    0.004049
#                3     0.282449  0.068740  0.063876      0.190510                    0.190510
#                4     1.249223  0.060799  1.501809      0.277166                    0.277166
#                ...        ...       ...       ...           ...                         ...
#                5050  0.085051  0.082166  0.052074      0.038751                    0.038751
#                5051  0.061552  0.092952  0.050170      0.371860                    0.371860
#                5052  0.022190  0.108359  0.038838      0.900973                    0.900973
#                5053  0.271338  1.227422  1.267151      0.510374                    0.510374
#                5054  1.339988  1.713009  1.934349      0.768445                    0.768445
#
#                [5055 rows x 9 columns]
# ic| merged_df:                        Protein.Group  control_I  control_I.1  control_I.2  \
#                0     A0A0B4J2D5;P0DPI2-GATD3;GATD3B
# ic| filtered:                       Protein.Group  control_I  control_I.1  control_I.2  \
#               9                      A1L0T0-ILVBL   0.318976     0.318976     0.318976
#               28                    A8MXV4-NUDT19   0.028972     0.028972     0.028972
#               39    Cont_Q2KJD0;P07437-TUBB;TUBB5  15.199791    15.199791    15.199791
#               64                      O00257-CBX4   0.119919     0.119919     0.119919
#               99                     O00560-SDCBP   0.925791     0.925791     0.925791
#               ...                             ...        ...          ...          ...
#               4996                    Q9Y5X1-SNX9   0.822768     0.822768     0.822768
#               5008                    Q9Y624-F11R   0.227516     0.227516     0.227516
#               5027                  Q9Y6D9-MAD1L1   1.375668     1.375668     1.375668
#               5028                   Q9Y6E0-STK24   0.199137     0.199137     0.199137
#               5044                   Q9Y6N1-COX11   0.117533     0.117533     0.117533
#
#                         FAC_I     FAC_II    FAC_III  ANOVA_pvalue  \
#               9      0.171083   0.142590   0.185368  6.853239e-04
#               28     0.297442   0.402452   0.307946  8.208098e-05
#               39    17.063500  17.250220  17.589683  1.293653e-04
#               64     0.329457   0.326120   0.339568  2.197218e-07
#               99     1.179665   1.120360   1.216037  6.210966e-04
#               ...         ...        ...        ...           ...
#               4996   0.042111   0.046900   0.090041  4.343487e-05
#               5008   0.143660   0.143400   0.117850  8.523179e-04
#               5027   0.941164   1.026559   1.009925  2.389675e-04
#               5028   0.038327   0.058673   0.074977  6.868459e-04
#               5044   0.046621   0.041214   0.048494  1.171331e-05
#
#                     FAC vs. control Tukey Test
#               9                   6.853239e-04
#               28                  8.208098e-05
#               39                  1.293653e-04
#               64                  2.197218e-07
#               99                  6.210966e-04
#               ...                          ...
#               4996                4.343487e-05
#               5008                8.523179e-04
#               5027                2.389675e-04
#               5028                6.868459e-04
#               5044                1.171331e-05
#
#               [320 rows x 9 columns]
# ic| cols: ['Protein.Group',
#            'control_I',
#            'control_II',
#            'control_III',
#            'FAC_I',
#            'FAC_II',
#            'FAC_III']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 clustermap_anova.plot_clustermap(path, samples)
#
# File c:\phd projects\silac_dia_statistics\sdia_stats\visualization\clustermap_anova.py:60, in plot_clustermap(path, samples)
#      57 nsp_merged = merge_data(nsp_df, nsp_anova)
#      58 light_merged = merge_data(light_df, light_anova)
# ---> 60 anova_clustermap(nsp_merged, path, samples, "nsp")
#      61 anova_clustermap(light_merged, path, samples, "light")
#
# File c:\phd projects\silac_dia_statistics\sdia_stats\visualization\clustermap_anova.py:21, in anova_clustermap(df, path, samples, title)
#      19 cols = ['Protein.Group']+samples
#      20 ic(cols)
# ---> 21 filtered = filtered[cols]
#      22 print('HEREEEEEEEEEEEEEE')
#      23 ic(filtered)
#
# File ~\AppData\Local\miniconda3\envs\silac_dia_statistics0.1.0\lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\miniconda3\envs\silac_dia_statistics0.1.0\lib\site-packages\pandas\core\indexes\base.py:5876, in Index._get_indexer_strict(self, key, axis_name)
#    5873 else:
#    5874     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5876 self._raise_if_missing(keyarr, indexer, axis_name)
#    5878 keyarr = self.take(indexer)
#    5879 if isinstance(key, Index):
#    5880     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Local\miniconda3\envs\silac_dia_statistics0.1.0\lib\site-packages\pandas\core\indexes\base.py:5938, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5935     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5937 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5938 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['control_II', 'control_III'] not in index"
