# %% [markdown]
# # Preprocessing example

# %% [markdown]
# ## Imputation and sample normalization

# %%
from sdia_stats.preprocessing.imputation import process_intensities
from sdia_stats.preprocessing.sample_norm import normalize_samples
# Out:
# Saved to G:/My Drive/Data/data/eIF4F pilot/imputed\normalized\light.csv
# Saved to G:/My Drive/Data/data/eIF4F pilot/imputed\normalized\nsp.csv
# Saved to G:/My Drive/Data/data/eIF4F pilot/imputed\normalized\total.csv
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 2
#       1 from sdia_stats.preprocessing.imputation import process_intensities
# ----> 2 from sdia_stats.preprocessing.sample_norm import normalize_samples
#
# ImportError: cannot import name 'normalize_samples' from 'sdia_stats.preprocessing.sample_norm' (c:\phd projects\silac_dia_statistics\sdia_stats\preprocessing\sample_norm.py)

# %%
path = 'G:/My Drive/Data/data/eif4f pilot stats/'
subset = ['e+8h','e-8h', 'g1-8h', 'g1+8h','g2-8h', 'g2+8h','g3-8h', 'g3+8h']
process_intensities(path, subset, quantification='href', plot_imputation=False)
# Out:
# c:\phd projects\silac_dia_statistics\sdia_stats\preprocessing\imputation.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('keep_row', axis=1, inplace=True)
# c:\phd projects\silac_dia_statistics\sdia_stats\preprocessing\imputation.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('keep_row', axis=1, inplace=True)
# c:\phd projects\silac_dia_statistics\sdia_stats\preprocessing\imputation.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('keep_row', axis=1, inplace=True)
# Folder reports already exists at G:/My Drive/Data/data/eif4f pilot stats/imputed

# %%
normalize_samples(path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 normalize_samples(path)
#
# NameError: name 'normalize_samples' is not defined
