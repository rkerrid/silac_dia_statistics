# %%
#preprocessing

# %%
from sdia_stats.preprocessing import imputation
from sdia_stats.preprocessing import sample_norm

# %%
path = 'G:/My Drive/Data/data/poc 3/N/'

# %%
imputation.process_intensities(path, quantification='dlfq')
# Out:
# c:\phd projects\silac_dia_statistics\sdia_stats\preprocessing\imputation.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('keep_row', axis=1, inplace=True)
# c:\phd projects\silac_dia_statistics\sdia_stats\preprocessing\imputation.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('keep_row', axis=1, inplace=True)
# c:\phd projects\silac_dia_statistics\sdia_stats\preprocessing\imputation.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('keep_row', axis=1, inplace=True)
# Folder reports created successfully at G:/My Drive/Data/data/poc 3/N/imputed

# %%
sample_norm.normalize_samples(path)
# Out:
# Saved to G:/My Drive/Data/data/poc 3/N/imputed\normalized\light.csv
# Saved to G:/My Drive/Data/data/poc 3/N/imputed\normalized\nsp.csv
# Saved to G:/My Drive/Data/data/poc 3/N/imputed\normalized\total.csv
