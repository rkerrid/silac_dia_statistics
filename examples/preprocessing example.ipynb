# %% [markdown]
# # Preprocessing example

# %% [markdown]
# ## Imputation and sample normalization

# %%
from sdia_stats.preprocessing import adapted_imputation 
from sdia_stats.preprocessing import normalize_samples
from sdia_stats.preprocessing import filter_contams_and_non_valid_rows

# %%
path = 'G:/My Drive/Data/data/poc4/H/protein intensities/'
path = 'G:/My Drive/Data/data/20240306 eIF 5 lines/3d G3 G2/protein_groups/'
group = {'3D_08-': ['3D_08+'], 
         '3D_28-':['3D_08+']
             }

# %%
metadata_path = 'G:/My Drive/Data/data/eif4g optimization/'
filter_contams_and_non_valid_rows.filter_protein_intensities(path, metadata_path, 'href')

# %%
normalize_samples.main(path, group)
# Out:
# ic| metadata.columns.values.tolist(): ['Run', 'Sample', 'Treatment']
# ic| metadata.columns.values.tolist(): ['Run', 'Sample', 'Treatment']
# ic| metadata.columns.values.tolist(): ['Run', 'Sample', 'Treatment']
# ic| metadata.columns.values.tolist(): ['Run', 'Sample', 'Treatment']
# ic| metadata.columns.values.tolist(): ['Run', 'Sample', 'Treatment']
# ic| metadata.columns.values.tolist(): ['Run', 'Sample', 'Treatment']
# ic| metadata.columns.values.tolist(): ['Run', 'Sample', 'Treatment']
# ic| metadata.columns.values.tolist(): ['Run', 'Sample', 'Treatment']
# ic| metadata.columns.values.tolist(): ['Run', 'Sample'
# [('3D_08-', '3D_08+', -0.12320532134030415), ('3D_28-', '3D_08+', 0.1915446208417535)]
# , 'Treatment']
# ic| metadata.columns.values.tolist(): ['Run', 'Sample', 'Treatment']
# ic| metadata.columns.values.tolist(): ['Run', 'Sample', 'Treatment']
# ic| metadata.columns.values.tolist(): ['Run', 'Sample', 'Treatment']
# ic| metadata.columns.values.tolist(): ['Run', 'Sample', 'Treatment']
# ic| metadata.columns.values.tolist(): ['Run', 'Sample', 'Treatment']
# Folder reports created successfully at G:/My Drive/Data/data/20240306 eIF 5 lines/3d G3 G2/protein_groups/normalized

# %%
path = 'G:/My Drive/Data/data/20240306 eIF 5 lines/3d G3 G2/protein_groups/normalized/'
control_samples = list(group.keys())
adapted_imputation.process_intensities(path, control_samples, plot_imputation=True) #optional parameters: subset, quantification='href', plot_imputation=False
# Out:
# import data
# Subset data
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 3
#       1 path = 'G:/My Drive/Data/data/20240306 eIF 5 lines/3d G3 G2/protein_groups/normalized/'
#       2 control_samples = list(group.keys())
# ----> 3 adapted_imputation.process_intensities(path, control_samples, plot_imputation=True) #optional parameters: subset, quantification='href', plot_imputation=False
#
# File c:\phd projects\silac_dia_statistics\sdia_stats\preprocessing\adapted_imputation.py:205, in process_intensities(path, control_samples, subset, plot_imputation)
#     203 print('Subset data')
#     204 metadata = subset_metadata(metadata, subset)
# --> 205 light = subset_data(light, metadata)
#     206 nsp = subset_data(nsp, metadata)
#     207 print('preprocess data')
#
# File c:\phd projects\silac_dia_statistics\sdia_stats\preprocessing\adapted_imputation.py:55, in subset_data(df, metadata)
#      53 relevant_samples = metadata['Sample'].values.tolist()
#      54 columns_to_keep = ['Protein.Group'] + relevant_samples
# ---> 55 return df[columns_to_keep]
#
# File ~\AppData\Local\miniconda3\envs\silac_dia_statistics0.1.0\lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\miniconda3\envs\silac_dia_statistics0.1.0\lib\site-packages\pandas\core\indexes\base.py:5876, in Index._get_indexer_strict(self, key, axis_name)
#    5873 else:
#    5874     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5876 self._raise_if_missing(keyarr, indexer, axis_name)
#    5878 keyarr = self.take(indexer)
#    5879 if isinstance(key, Index):
#    5880     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Local\miniconda3\envs\silac_dia_statistics0.1.0\lib\site-packages\pandas\core\indexes\base.py:5938, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5935     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5937 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5938 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['3D_28_1 +', '3D_28_2 +', '3D_28_3 +', 'G3_08_1 -', 'G3_08_2 -', 'G3_08_3 -', 'G3_08_1 +', 'G3_08_2 +', 'G3_08_3 +', 'G3_28_1 -', 'G3_28_2 -', 'G3_28_3 -', 'G3_28_1 +', 'G3_28_2 +', 'G3_28_3 +', 'G2_08_1 -', 'G2_08_2 -', 'G2_08_3 -', 'G2_08_1 +', 'G2_08_2 +', 'G2_08_3 +', 'G2_28_1 -', 'G2_28_2 -', 'G2_28_3 -', 'G2_28_1 +', 'G2_28_2 +', 'G2_28_3 +', '3D_08_1 +', '3D_08_2 +', '3D_08_3 +'] not in index"
