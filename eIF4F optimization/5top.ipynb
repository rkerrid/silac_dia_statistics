# %%
import alphastats 
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = "G:/My Drive/Data/data/eIF4F optimization/protein intensities/"
loader_nsp = alphastats.GenericLoader(f"{path}nsp_href.csv", 
                                  intensity_column = '[Sample]',
                                   index_column="Protein.Group")

# %%
df_nsp = alphastats.DataSet(
    loader = loader_nsp,
    metadata_path = f"G:/My Drive/Data/data/eIF4F optimization/meta_8hour.xlsx",
    sample_column = 'Sample')
# Out:
# DataSet has been created.
# Attributes of the DataSet can be accessed using:
# DataSet.rawinput:	 Raw Protein data.
# DataSet.mat:		Processed data matrix with ProteinIDs/ProteinGroups as columns and samples as rows. All computations are performed on this matrix.
# DataSet.metadata:	Metadata for the samples in the matrix. Metadata will be matched with DataSet.mat when needed (for instance Volcano Plot).

# %%
df_nsp.preprocess(subset=True)
# Out:
# Data has been log2-transformed.

# %%
top_list = ["P11940-PABPC1","P13693-TPT1","P13639-EEF2","P62750-RPL23A","P35268-RPL22"]
#ribosomal
top_list_ribosomal =["P62750-RPL23A",
"P35268-RPL22",
"P27635-RPL10",
"P30050-RPL12",
"P40429-RPL13A",
"Q02543-RPL18A",
"P39023-RPL3",
"P49207-RPL34",
"P46783-RPS10",
"P25398-RPS12",
"P62269-RPS18",
"P39019-RPS19",
"P62851-RPS25",
"P46782-RPS5"]
#
top_list_translation_factors=[#"P68104-EEF1A1",
"Q05639-EEF1A2",
"P24534-EEF1B2",
"P29692-EEF1D",
"P13639-EEF2",
"Q9BY44-EIF2A",
"P60228-EIF3E",
"O00303-EIF3F",
"O75821-EIF3G",
"O15372-EIF3H",
"Q9Y262-EIF3L",
"P23588-EIF4B",
"P56192-MARS1"]

top_list_rbps = ["Q14444-CAPRIN1",
"O75534-CSDE1",
"P51114-FXR1",
"Q15366-PCBP2",
"O95793-STAU1"]
top_list_rrna_processing =["Q14137-BOP1",
"Q9NX24-NHP2",
"Q9ULX3-NOB1"]

top_chaperones = ["P46379-BAG6",
"P08238-HSP90AB1",
"P11142-HSPA8"]

# %%
for protein in top_list_ribosomal:
    
    plot = df_nsp.plot_intensity(
        method="all",
        protein_id=protein, 
        group="eIF4F", # column in metadata
        subgroups=["eIF4G3-","eIF4G3+","eIF4G2-","eIF4G2+","eIF4G1-","eIF4G1+","eIF4E-","eIF4E+"], # we only want to see T2DM and T2DM+NAFLD
        add_significance=True # add bar with pvalue
        )
    plot.update_layout(plot_bgcolor="white", paper_bgcolor="white", height=400).show()
# Out:
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# ...

# %%
for protein in top_list_translation_factors:
    
    plot = df_nsp.plot_intensity(
        method="all",
        protein_id=protein, 
        group="eIF4F", # column in metadata
        subgroups=["eIF4G3-","eIF4G3+","eIF4G2-","eIF4G2+","eIF4G1-","eIF4G1+","eIF4E-","eIF4E+"], # we only want to see T2DM and T2DM+NAFLD
        add_significance=True # add bar with pvalue
        )
    plot.update_layout(plot_bgcolor="white", paper_bgcolor="white", height=400).show()
# Out:
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.

# %%
for protein in top_list_rbps:
    
    plot = df_nsp.plot_intensity(
        method="all",
        protein_id=protein, 
        group="eIF4F", # column in metadata
        subgroups=["eIF4G3-","eIF4G3+","eIF4G2-","eIF4G2+","eIF4G1-","eIF4G1+","eIF4E-","eIF4E+"], # we only want to see T2DM and T2DM+NAFLD
        add_significance=True # add bar with pvalue
        )
    plot.update_layout(plot_bgcolor="white", paper_bgcolor="white", height=400).show()
# Out:
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.

# %%
for protein in top_list_rrna_processing:
    
    plot = df_nsp.plot_intensity(
        method="all",
        protein_id=protein, 
        group="eIF4F", # column in metadata
        subgroups=["eIF4G3-","eIF4G3+","eIF4G2-","eIF4G2+","eIF4G1-","eIF4G1+","eIF4E-","eIF4E+"], # we only want to see T2DM and T2DM+NAFLD
        add_significance=True # add bar with pvalue
        )
    plot.update_layout(plot_bgcolor="white", paper_bgcolor="white", height=400).show()
# Out:
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.

# %%
for protein in top_chaperones:
    
    plot = df_nsp.plot_intensity(
        method="all",
        protein_id=protein, 
        group="eIF4F", # column in metadata
        subgroups=["eIF4G3-","eIF4G3+","eIF4G2-","eIF4G2+","eIF4G1-","eIF4G1+","eIF4E-","eIF4E+"], # we only want to see T2DM and T2DM+NAFLD
        add_significance=True # add bar with pvalue
        )
    plot.update_layout(plot_bgcolor="white", paper_bgcolor="white", height=400).show()
# Out:
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# WARNING:root:Signficane can only be estimated when there are two groups plotted.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 3
#       1 for protein in top_chaperones:
# ----> 3     plot = df_nsp.plot_intensity(
#       4         method="all",
#       5         protein_id=protein,
#       6         group="eIF4F", # column in metadata
#       7         subgroups=["eIF4G3-","eIF4G3+","eIF4G2-","eIF4G2+","eIF4G1-","eIF4G1+","eIF4E-","eIF4E+"], # we only want to see T2DM and T2DM+NAFLD
#       8         add_significance=True # add bar with pvalue
#       9         )
#      10     plot.update_layout(plot_bgcolor="white", paper_bgcolor="white", height=400).show()
#
# ...
